# %%
import cv2
import matplotlib.pyplot as plt
 
l_img = cv2.imread('./' + 'kyung1_re_crop_resize' + '.jpg')
plt.imshow(l_img)
plt.show()
# r_img = cv2.imread('./single_test_multimodal/' + ing_num2 + '.jpg')
l_img = cv2.cvtColor(l_img, cv2.COLOR_BGR2RGB)
# r_img = cv2.cvtColor(r_img, cv2.COLOR_BGR2RGB)
plt.imshow(l_img)
plt.show()
